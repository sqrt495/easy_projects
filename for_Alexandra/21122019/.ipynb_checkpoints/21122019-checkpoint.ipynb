# %%
# задача 2

# импорт библиотки
import pandas as pd

# открываем файл
df = pd.read_csv('kc_house_data.csv')

# печатаем первые 5 строк
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7      1180.0              0
# 1      7242     2.0           0     0  ...      7      2170.0            400
# 2     10000     1.0           0     0  ...      6       770.0              0
# 3      5000     1.0           0     0  ...      7      1050.0            910
# 4      8080     1.0           0     0  ...      8      1680.0              0
#
# ...

# %%
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       2
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
new_df = df.groupby('yr_built').mean().iloc[:,1:2]
# new_df

# %%
new_df.plot()

# %%
bads = df.groupby('bedrooms').count()
bads # количество спален слева, количество даомов указано во всех столбцах
# можно так
bads['id']
# Out:
# bedrooms
# 0       13
# 1      199
# 2     2760
# 3     9824
# 4     6882
# 5     1601
# 6      272
# 7       38
# 8       13
# 9        6
# 10       3
# 11       1
# 33       1
# Name: id, dtype: int64

# %%
a =  df.groupby('bedrooms')

# %%
a = bads['id']
bads
# Out:
#             id  date  price  bathrooms  sqft_living  sqft_lot  floors  \
# bedrooms
# 3         9824  9824   9824       9824         9824      9824    9824
# 4         6882  6882   6882       6882         6882      6882    6882
# 2         2760  2760   2760       2760         2760      2760    2760
# 5         1601  1601   1601       1601         1601      1601    1601
# 6          272   272    272        272          272       272     272
# 1          199   199    199        199          199       199     199
# 7           38    38     38         38           38        38      38
# 0           13    13     13         13           13        13      13
# 8           13    13     13         13           13        13      13
# 9            6     6      6          6            6         6       6
# 10           3     3      3          3            3         3       3
# 11           1     1      1          1            1         1       1
# ...

# %%
bads['id'].plot.bar()

# %%
df.corr()
# Out:
#                      id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id             1.000000 -0.016762  0.001286   0.005160    -0.012258 -0.132109
# price         -0.016762  1.000000  0.308350   0.525138     0.702035  0.089661
# bedrooms       0.001286  0.308350  1.000000   0.515884     0.576671  0.031703
# bathrooms      0.005160  0.525138  0.515884   1.000000     0.754665  0.087740
# sqft_living   -0.012258  0.702035  0.576671   0.754665     1.000000  0.172826
# sqft_lot      -0.132109  0.089661  0.031703   0.087740     0.172826  1.000000
# floors         0.018525  0.256794  0.175429   0.500653     0.353949 -0.005201
# waterfront    -0.002721  0.266369 -0.006582   0.063744     0.103818  0.021604
# view           0.011592  0.397293  0.079532   0.187737     0.284611  0.074710
# condition     -0.023783  0.036362  0.028472  -0.124982    -0.058753 -0.008958
# grade          0.008130  0.667434  0.356967   0.664983     0.762704  0.113621
# ...
